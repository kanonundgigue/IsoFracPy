# %% [markdown]
# # Sensitivity test

# %%
notebook_name = "sensitivity_test_d18O"

# %%
from sensitivity_test import *

# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
mpl.rcParams['font.family'] = 'sans-serif'
# 優先順位を Helvetica → Arial の順に設定（必要なら他のフォントを追加）
mpl.rcParams['font.sans-serif'] = ['Helvetica', 'Arial']    
from param_test import set_param

# %% [markdown]
# ## あらかじめ絞れるパラメータ

# %% [markdown]
# ### temperature of sea surface of initial evaporation

# %% [markdown]
# Nakamura et al. 2008 GRL　Fig. 1より、typicalな　SST frontは5-15度くらい。その周辺でstorm track活動が活発になると考える。 -> 蒸発起源SST

# %%
ISO_TYPE = "H218O"

param_fix_dict = {
    "ISO_TYPE": ISO_TYPE,
    "temp_sea_init_list": [5, 10, 15]    ,
    "BOOL_REEVAP": False, # 十分湿っている雲には返らない
    "temp_surf": [0],
}

# %% [markdown]
# ### Tuning

# %% [markdown]
# 全ての組み合わせを試す。

# %%
param_test_dict = set_param(ISO_TYPE)

# %%
title=f"tuning_parallel_{ISO_TYPE}"

# if not os.path.exists(f"tables/{title}_0.csv"):
run_sensitivity_analysis(
    param_test_dict=param_test_dict,
    param_fix_dict=param_fix_dict,
    iso_model_dir=iso_model_dir,
    GENERATE_FIG = False,
    title=title
)
# Out:
# The following CSV files already exist:
# New file is created:
# - /Users/kanon/Work/IsoFracPy/analysis/tables/tuning_parallel_H218O_0.csv
# New file is created:
# - /Users/kanon/Work/IsoFracPy/analysis/tables/tuning_parallel_H218O_0.csv
# New file is created:
# - /Users/kanon/Work/IsoFracPy/analysis/tables/tuning_parallel_H218O_1.csv
# New file is created:
# - /Users/kanon/Work/IsoFracPy/analysis/tables/tuning_parallel_H218O_2.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 title=f"tuning_parallel_{ISO_TYPE}"
#       3 # if not os.path.exists(f"tables/{title}_0.csv"):
# ----> 4 run_sensitivity_analysis(
#       5     param_test_dict=param_test_dict,
#       6     param_fix_dict=param_fix_dict,
#       7     iso_model_dir=iso_model_dir,
#       8     GENERATE_FIG = False,
#       9     title=title
#      10 )
#
# File ~/Work/IsoFracPy/analysis/sensitivity_test.py:121, in run_sensitivity_analysis(param_test_dict, param_fix_dict, xlim, ylim, fig_size_unit, subplot_hnum_max, title, iso_model_dir, results_dir, GENERATE_FIG, BOOL_SAVE_FIG, notebook_name, max_workers)
#     113 futures = [
#     114     executor.submit(
#     115         process_combination, index, combination, param_test_dict, param_fix_dict, results_dir, title, GENERATE_FIG,
#    (...)
#     118     for index, combination in enumerate(param_combinations)
#     119 ]
#     120 for future in concurrent.futures.as_completed(futures):
# --> 121     index = futures[future]
#     122     try:
#     123         future.result()
#
# TypeError: list indices must be integers or slices, not Future
